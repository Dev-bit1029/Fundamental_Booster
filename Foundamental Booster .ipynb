# %% [markdown]
# # Foundamental Booster

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
name = "Dev Thakkar"
print("hello!",name)
# Out:
# hello! Dev Thakkar

# %%
name = input("enter your Name ")
Age = I= input("Enter Your Age")
Height = input("Enter Your Height ")
Number = input("Enter Your Favourit Number ")

print("Hello",name)
print ("Age :- " ,Age )
print("Height :- " ,Height )
print("Number :- ",Number )
# Out:
# enter your Name  DEV THAKKAR
# Enter Your Age 20
# Enter Your Height  162
# Enter Your Favourit Number  7
# Hello DEV THAKKAR
# Age :-  20
# Height :-  162
# Number :-  7

# %%
print(" you are", Age , "years old and", Height,"meters tall")
# Out:
#  you are 20 years old and 162 meters tall

# %%
name = "Dev Thakkar"
age = "20"
height = "160"
number = "7"

print(id(number))
print(id(name))
print(id(age))
print(id(height))
# Out:
# 140703998384128
# 1932717842800
# 1932649044832
# 1932689652832

# %%
name = "Dev Thakkar"
age = 20
height = 162.52
number = 7

print(type(name))
print(type(age))
print(type(height))
print(type(number))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
# Age Calculator using input()

birth_year = int(input("Enter your birth year: "))
current_year = int(input("Enter current year: "))

age = current_year - birth_year

print("Your age is:", age)
# Out:
# Enter your birth year:  2006
# Enter current year:  2026
# Your age is: 20

# %%
a,b,c,d = 1,2,3.5,4.5
print(a)
print(b)
print("Hello python")
print(c)
print(d)
# Out:
# 1
# 2
# Hello python
# 3.5
# 4.5

# %%
a,b,c,d = 110,120,130,140
f = a+b
g = c*d 
h = a-b
j = c/d

# %%
print(f)
print(g)
print(h)
print(j)
# Out:
# 230
# 18200
# -10
# 0.9285714285714286

# %% [markdown]
# # successful Foundamental Booster
